# %% [markdown]
# <a href="https://colab.research.google.com/github/mohdraavi/car_price/blob/main/Untitled142.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/data_cardiovascular_risk.csv')

# %%
df.head()
# Out:
#    id  age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0   0   64        2.0   F        YES         3.0     0.0                0
# 1   1   36        4.0   M         NO         0.0     0.0                0
# 2   2   46        1.0   F        YES        10.0     0.0                0
# 3   3   50        1.0   M        YES        20.0     0.0                0
# 4   4   64        1.0   F        YES        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    221.0  148.0   85.0    NaN       90.0     80.0
# 1             1         0    212.0  168.0   98.0  29.77       72.0     75.0
# 2             0         0    250.0  116.0   71.0  20.35       88.0     94.0
# 3             1         0    233.0  158.0   88.0  28.26       68.0     94.0
# 4             0         0    241.0  136.5   85.0  26.42       70.0     77.0
#
#    TenYearCHD
# 0           1
# 1           0
# 2           0
# ...

# %%
df.drop(columns=['id'],inplace=True)

# %%
df.head()
# Out:
#    age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0   64        2.0   F        YES         3.0     0.0                0
# 1   36        4.0   M         NO         0.0     0.0                0
# 2   46        1.0   F        YES        10.0     0.0                0
# 3   50        1.0   M        YES        20.0     0.0                0
# 4   64        1.0   F        YES        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    221.0  148.0   85.0    NaN       90.0     80.0
# 1             1         0    212.0  168.0   98.0  29.77       72.0     75.0
# 2             0         0    250.0  116.0   71.0  20.35       88.0     94.0
# 3             1         0    233.0  158.0   88.0  28.26       68.0     94.0
# 4             0         0    241.0  136.5   85.0  26.42       70.0     77.0
#
#    TenYearCHD
# 0           1
# 1           0
# 2           0
# 3           1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3390 entries, 0 to 3389
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              3390 non-null   int64
#  1   education        3303 non-null   float64
#  2   sex              3390 non-null   object
#  3   is_smoking       3390 non-null   object
#  4   cigsPerDay       3368 non-null   float64
#  5   BPMeds           3346 non-null   float64
#  6   prevalentStroke  3390 non-null   int64
#  7   prevalentHyp     3390 non-null   int64
#  8   diabetes         3390 non-null   int64
#  9   totChol          3352 non-null   float64
#  10  sysBP            3390 non-null   float64
#  11  diaBP            3390 non-null   float64
#  12  BMI              3376 non-null   float64
#  13  heartRate        3389 non-null   float64
#  14  glucose          3086 non-null   float64
#  15  TenYearCHD       3390 non-null   int64
# ...

# %%
df.shape
# Out:
# (3390, 16)

# %%
df.isnull().sum()
# Out:
# age                  0
# education           87
# sex                  0
# is_smoking           0
# cigsPerDay          22
# BPMeds              44
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             38
# sysBP                0
# diaBP                0
# BMI                 14
# heartRate            1
# glucose            304
# TenYearCHD           0
# dtype: int64

# %%
new_df = df.copy()

# %%
df['education'].unique() #mode
# Out:
# array([ 2.,  4.,  1.,  3., nan])

# %%
df['education'].value_counts()
# Out:
# 1.0    1391
# 2.0     990
# 3.0     549
# 4.0     373
# Name: education, dtype: int64

# %%
df['cigsPerDay'].unique()
# Out:
# array([ 3.,  0., 10., 20., 30., 35., 40., 15.,  9., 60., 17., 25.,  5.,
#        43.,  7., 50., 19., 18.,  1., 45.,  2.,  6., nan, 11.,  8.,  4.,
#        14., 16., 23., 13., 12., 70., 38.])

# %%
df['cigsPerDay'].value_counts() #mean
# Out:
# 0.0     1703
# 20.0     606
# 30.0     176
# 15.0     172
# 10.0     106
# 9.0      104
# 5.0      103
# 3.0       79
# 40.0      62
# 1.0       48
# 25.0      44
# 43.0      42
# 35.0      17
# 2.0       17
# 6.0       14
# 8.0       10
# 7.0        8
# 60.0       8
# 18.0       7
# 4.0        7
# 50.0       6
# 17.0       5
# 23.0       5
# 11.0       4
# 12.0       3
# 13.0       3
# 19.0       2
# 16.0       2
# 45.0       2
# 14.0       1
# 70.0       1
# 38.0       1
# Name: cigsPerDay, dtype: int64

# %%
df['BPMeds'].unique()
# Out:
# array([ 0., nan,  1.])

# %%
df['BPMeds'].value_counts() #mode
# Out:
# 0.0    3246
# 1.0     100
# Name: BPMeds, dtype: int64

# %%
df['totChol'].unique()   #mean
# Out:
# array([221., 212., 250., 233., 241., 272., 238., 295., 220., 326.,  nan,
#        210., 213., 227., 188., 240., 257., 267., 232., 199., 175., 164.,
#        226., 248., 245., 279., 273., 252., 198., 266., 216., 237., 193.,
#        293., 180., 206., 215., 208., 262., 270., 292., 346., 202., 340.,
#        334., 351., 235., 243., 196., 275., 186., 190., 268., 234., 264.,
#        156., 260., 225., 183., 246., 174., 288., 254., 150., 211., 161.,
#        274., 214., 195., 165., 302., 265., 251., 205., 209., 258., 222.,
#        247., 189., 173., 281., 382., 181., 200., 244., 218., 261., 229.,
#        291., 312., 170., 176., 290., 204., 239., 162., 314., 194., 271.,
#        313., 305., 285., 169., 224., 201., 185., 307., 179., 280., 219.,
#        391., 300., 253., 345., 278., 282., 255., 191., 439., 327., 287.,
#        236., 332., 207., 230., 155., 335., 325., 223., 231., 197., 184.,
#        310., 157., 228., 166., 303., 320., 163., 259., 178., 137., 217.,
# ...

# %%
df['BMI'].nunique() #mean
# Out:
# 1259

# %%
df['glucose'].unique() #mean
# Out:
# array([ 80.,  75.,  94.,  77.,  65.,  79.,  63.,  nan,  87.,  67.,  85.,
#        132.,  76., 100.,  70.,  60.,  73.,  81.,  68.,  66.,  78.,  96.,
#         72.,  61.,  69., 103.,  92., 105.,  93.,  89.,  64.,  83., 170.,
#         57.,  58.,  86.,  99., 107.,  55.,  90., 177.,  71., 118.,  59.,
#         74.,  84.,  82.,  95., 120., 173.,  91., 102., 163.,  88.,  62.,
#        205.,  97., 115.,  98., 268., 104., 137., 106., 348., 110., 122.,
#        108., 255., 140., 124., 244., 294., 112., 113., 254., 116.,  52.,
#         50., 114., 127.,  56., 135.,  45., 206.,  53., 101., 117., 126.,
#        131., 394., 123., 270., 320., 129., 142.,  54., 235.,  40., 150.,
#        136., 191.,  44., 119., 109., 121.,  43., 256., 145.,  47., 297.,
#        166., 172.,  48., 111., 215., 216., 368., 155., 148., 147., 223.,
#        225., 332., 210., 186., 386., 248., 193., 125., 167., 183., 260.,
#        274.])

# %%
# Calculate the mean of the specific column
column_mode = new_df['education'].mode()

# Impute missing values in the specific column with its mean
new_df ['education'].fillna(column_mode, inplace=True)

# %%
new_df.isnull().sum()
# Out:
# age                  0
# education           87
# sex                  0
# is_smoking           0
# cigsPerDay          22
# BPMeds              44
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             38
# sysBP                0
# diaBP                0
# BMI                 14
# heartRate            1
# glucose            304
# TenYearCHD           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# age                0
# education          0
# sex                0
# is_smoking         0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
df.head()
# Out:
#    age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 1   36        4.0   M         NO         0.0     0.0                0
# 2   46        1.0   F        YES        10.0     0.0                0
# 3   50        1.0   M        YES        20.0     0.0                0
# 4   64        1.0   F        YES        30.0     0.0                0
# 5   61        3.0   F         NO         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 1             1         0    212.0  168.0   98.0  29.77       72.0     75.0
# 2             0         0    250.0  116.0   71.0  20.35       88.0     94.0
# 3             1         0    233.0  158.0   88.0  28.26       68.0     94.0
# 4             0         0    241.0  136.5   85.0  26.42       70.0     77.0
# 5             1         0    272.0  182.0  121.0  32.80       85.0     65.0
#
#    TenYearCHD
# 1           0
# 2           0
# 3           1
# 4           0
# ...

# %%
df['is_smoking'].value_counts()
# Out:
# NO     1480
# YES    1447
# Name: is_smoking, dtype: int64

# %%
df['is_smoking']
# Out:
# 1        NO
# 2       YES
# 3       YES
# 4       YES
# 5        NO
#        ...
# 3384     NO
# 3385     NO
# 3386     NO
# 3387    YES
# 3389     NO
# Name: is_smoking, Length: 2927, dtype: object

# %%
def smoke(txt):
  if txt == 'YES':
    return 1
  else:
    return 0

# %%
df['is_smoking'] = df['is_smoking'].apply(smoke)

# %%
def gender(txt):
  if txt == 'M':
    return 1
  else:
    return 0

# %%
df['sex'] = df['sex'].apply(gender)

# %%
df.head()
# Out:
#    age  education  sex  is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 1   36        4.0    1           0         0.0     0.0                0
# 2   46        1.0    0           1        10.0     0.0                0
# 3   50        1.0    1           1        20.0     0.0                0
# 4   64        1.0    0           1        30.0     0.0                0
# 5   61        3.0    0           0         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 1             1         0    212.0  168.0   98.0  29.77       72.0     75.0
# 2             0         0    250.0  116.0   71.0  20.35       88.0     94.0
# 3             1         0    233.0  158.0   88.0  28.26       68.0     94.0
# 4             0         0    241.0  136.5   85.0  26.42       70.0     77.0
# 5             1         0    272.0  182.0  121.0  32.80       85.0     65.0
#
#    TenYearCHD
# 1           0
# 2           0
# 3           1
# ...

# %%
X = df.iloc[:,:-1].values  # Include all the feature columns you want to use

# Dependent Variable (Target)
y = df.iloc[:,-1:].values

# %%
X
# Out:
# array([[36.  ,  4.  ,  1.  , ..., 29.77, 72.  , 75.  ],
#        [46.  ,  1.  ,  0.  , ..., 20.35, 88.  , 94.  ],
#        [50.  ,  1.  ,  1.  , ..., 28.26, 68.  , 94.  ],
#        ...,
#        [46.  ,  1.  ,  0.  , ..., 21.96, 80.  , 84.  ],
#        [44.  ,  3.  ,  1.  , ..., 28.92, 73.  , 72.  ],
#        [54.  ,  3.  ,  0.  , ..., 29.88, 79.  , 92.  ]])

# %%
columns_name = df.columns

# %%
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
X_train, X_test, Y_train, Y_test = train_test_split( X , y , test_size = 0.3, random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

# %%
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

# %%
train_accuracy = accuracy_score(Y_train, train_predictions)
test_accuracy = accuracy_score(Y_test, test_predictions)

# %%
train_accuracy
# Out:
# 0.85546875

# %%
test_accuracy
# Out:
# 0.8475540386803185

# %%
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],  # Regularization parameter
    'penalty': ['l1', 'l2']  # Regularization penalty ('l1' or 'l2')
}
# Create GridSearchCV with cross-validation
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)

# %%
grid_search.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %%
best_params = grid_search.best_params_
best_params
# Out:
# {'C': 0.001, 'penalty': 'l2'}

# %%
best_model = LogisticRegression(C= 0.01, penalty='l2')

# %%
best_model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=0.01)

# %%
b_train_predictions = best_model.predict(X_train)
b_test_predictions = best_model.predict(X_test)

# %%
b_train_accuracy = accuracy_score(Y_train, b_train_predictions)
b_test_accuracy = accuracy_score(Y_test, b_test_predictions)

# %%
b_train_accuracy
# Out:
# 0.8544921875

# %%
b_test_accuracy
# Out:
# 0.8395904436860068

# %%
from sklearn.tree import DecisionTreeClassifier
dt =  DecisionTreeClassifier()

# %%
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_train_predictions = dt.predict(X_train)
dt_test_predictions = dt.predict(X_test)

# %%
dt_train_accuracy = accuracy_score(Y_train, dt_train_predictions)
dt_test_accuracy = accuracy_score(Y_test, dt_test_predictions)

# %%
print(dt_train_accuracy)
print(dt_test_accuracy )
# Out:
# 1.0
# 0.7622298065984073

# %%
param_grid = {
    'criterion': ['gini', 'entropy'],  # Splitting criterion
    'max_depth': [None, 10, 20, 30, 40, 50],  # Maximum depth of the tree
    'min_samples_split': [2, 5, 10],  # Minimum samples required to split an internal node
    'min_samples_leaf': [1, 2, 4]  # Minimum samples required at a leaf node
}

# Create GridSearchCV with cross-validation
grid_search = GridSearchCV(estimator=dt, param_grid=param_grid, cv=5)

# Perform the grid search to find the best hyperparameters
grid_search.fit(X_train, Y_train)

# Get the best hyperparameters from the grid search
best_params = grid_search.best_params_

# %%
best_params
# Out:
# {'criterion': 'gini',
#  'max_depth': 10,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2}

# %%
b_dt =  DecisionTreeClassifier(criterion= 'gini',
 max_depth= 10,
 min_samples_leaf= 1,
 min_samples_split= 5)

# %%
b_dt.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_split=5)

# %%
b_dt_train_predictions = b_dt.predict(X_train)
b_dt_test_predictions = b_dt.predict(X_test)

# %%
b_dt_train_accuracy = accuracy_score(Y_train, b_dt_train_predictions)
b_dt_test_accuracy = accuracy_score(Y_test, b_dt_test_predictions)

# %%
print(b_dt_train_accuracy)
print(b_dt_test_accuracy )
# Out:
# 0.9150390625
# 0.8225255972696246

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rand_model =  RandomForestClassifier()

# %%
rand_model.fit(X_train,Y_train)
# Out:
# <ipython-input-68-83ae1819497e>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rand_model.fit(X_train,Y_train)
# RandomForestClassifier()

# %%
rf_train_predictions = rand_model.predict(X_train)
rf_test_predictions = rand_model.predict(X_test)

# %%
rf_train_accuracy = accuracy_score(Y_train, rf_train_predictions)
rf_test_accuracy = accuracy_score(Y_test, rf_test_predictions)

# %%
print(rf_train_accuracy)
print(rf_test_accuracy )
# Out:
# 1.0
# 0.8361774744027304

# %%
# Define the hyperparameter grid to search
param_grid = {
    'n_estimators': [100, 200, 300],  # Number of trees in the forest
    'criterion': ['gini', 'entropy'],  # Splitting criterion
    'max_depth': [None, 10, 20, 30, 40, 50],  # Maximum depth of the trees
    'min_samples_split': [2, 5, 10],  # Minimum samples required to split an internal node
    'min_samples_leaf': [1, 2, 4]  # Minimum samples required at a leaf node
}

# Create GridSearchCV with cross-validation
grid_search = GridSearchCV(estimator=rand_model, param_grid=param_grid, cv=5)

# Perform the grid search to find the best hyperparameters
grid_search.fit(X_train, Y_train)

# Get the best hyperparameters from the grid search
best_params = grid_search.best_params_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
best_params

# %%
b_rand_model =  RandomForestClassifier()

# %%
rand_model.fit(X_train,Y_train)

# %%
brf_train_predictions = dt.predict(X_train)
brf_test_predictions = dt.predict(X_test)

# %%
print(rf_train_accuracy)
print(rf_test_accuracy )
