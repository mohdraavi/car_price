# %% [markdown]
# <a href="https://colab.research.google.com/github/mohdraavi/car_price/blob/main/Untitled138.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/train.csv')

# %%
df.head()
# Out:
#    v.id  on road old  on road now  years      km  rating  condition  economy  \
# 0     1       535651       798186      3   78945       1          2       14
# 1     2       591911       861056      6  117220       5          9        9
# 2     3       686990       770762      2  132538       2          8       15
# 3     4       573999       722381      4  101065       4          3       11
# 4     5       691388       811335      6   61559       3          9       12
#
#    top speed  hp  torque  current price
# 0        177  73     123       351318.0
# 1        148  74      95       285001.5
# 2        181  53      97       215386.0
# 3        197  54     116       244295.5
# 4        160  53     105       531114.5

# %%
df['condition'].value_counts()
# Out:
# 6     118
# 9     112
# 5     109
# 8     100
# 7      96
# 1      96
# 3      95
# 10     93
# 4      93
# 2      88
# Name: condition, dtype: int64

# %%
df.isnull().sum()
# Out:
# v.id             0
# on road old      0
# on road now      0
# years            0
# km               0
# rating           0
# condition        0
# economy          0
# top speed        0
# hp               0
# torque           0
# current price    0
# dtype: int64

# %%
df.describe()
# Out:
#               v.id    on road old  on road now        years             km  \
# count  1000.000000    1000.000000    1000.0000  1000.000000    1000.000000
# mean    500.500000  601648.286000  799131.3970     4.561000  100274.430000
# std     288.819436   58407.246204   57028.9502     1.719079   29150.463233
# min       1.000000  500265.000000  700018.0000     2.000000   50324.000000
# 25%     250.750000  548860.500000  750997.7500     3.000000   74367.500000
# 50%     500.500000  601568.000000  798168.0000     5.000000  100139.500000
# 75%     750.250000  652267.250000  847563.2500     6.000000  125048.000000
# max    1000.000000  699859.000000  899797.0000     7.000000  149902.000000
#
#             rating    condition      economy   top speed          hp  \
# count  1000.000000  1000.000000  1000.000000  1000.00000  1000.00000
# mean      2.988000     5.592000    11.625000   166.89300    84.54600
# std       1.402791     2.824449     2.230549    19.28838    20.51694
# ...

# %%
df.drop(["v.id", 'on road old', 'on road now'], inplace=True, axis = 1)
df.head()
# Out:
#    years      km  rating  condition  economy  top speed  hp  torque  \
# 0      3   78945       1          2       14        177  73     123
# 1      6  117220       5          9        9        148  74      95
# 2      2  132538       2          8       15        181  53      97
# 3      4  101065       4          3       11        197  54     116
# 4      6   61559       3          9       12        160  53     105
#
#    current price
# 0       351318.0
# 1       285001.5
# 2       215386.0
# 3       244295.5
# 4       531114.5

# %%
import matplotlib.pyplot as plt

# Sample data (replace this with your own dataset)


# Create a histogram
plt.hist(df['current price'], bins=10, color='skyblue', edgecolor='black')  # Adjust the number of bins as needed

# Customize the plot (add labels, title, etc.)
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram Example')

# Show the histogram
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.hist(df['current price'], bins=30, density=True, color='skyblue', edgecolor='black')
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
#plotting the distribution of all features.
for col in df.columns:
  plt.figure(figsize=(10,6))
  sns.distplot(df[col])
  plt.xlabel(col,fontsize=12)

  plt.axvline(df[col].mean(),linewidth='2',color='red')
  plt.axvline(df[col].median(),linewidth='2',color='green',linestyle='dashed')
# Out:
# <ipython-input-15-22fe6b547bc0>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# <ipython-input-15-22fe6b547bc0>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# <ipython-input-15-22fe6b547bc0>:4: UserWarning:
#
# ...

# %%
#Correlation heatmap between each variables
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(), cmap="Spectral", cbar_kws={'shrink': .6}, square=True, annot=True, fmt='.2f', linewidths=.8)
plt.show()

# %%
for col in df.columns:
  plt.figure(figsize=(7,5))
  sns.boxplot(df[col],color='yellow')
  plt.xlabel(col,fontsize=14)
  plt.show()

# %%
for col in df.columns[:-1]:
  fig =plt.figure(figsize=(15,7))
  ax = fig.gca()
  feature = df[col]
  label = df['current price']
  correlation= feature.corr(label)
  plt.scatter(x=feature,y=label)

  plt.xlabel(col)
  plt.ylabel('Close')
  ax.set_title('Close vs ' + col + '- correlation ' + str(round(correlation,2)))
  z = np.polyfit(df[col],label,1)
  y_hat = np.poly1d(z)(df[col])
  plt.plot(df[col],y_hat,'r--',lw=1)

# %% [markdown]
# data splitting

# %%
X= df.iloc[:,:-1].values
y = df.iloc[:,-1:].values

# %%
from sklearn.model_selection import train_test_split
# Split your data to train and test. Choose Splitting ratio wisely.
X_train, X_test, Y_train, Y_test = train_test_split( X , y , test_size = 0.3, random_state = 42)

# %%
X_train.shape
# Out:
# (700, 8)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(X_train)
x_test = scaler.transform(X_test)

# %%
x_train
# Out:
# array([[ 1.39988882, -0.08624424,  0.73726821, ...,  0.45444286,
#          1.64703317, -1.36650994],
#        [-0.32735355, -1.22372594, -1.38946701, ...,  1.60266599,
#          0.31383145,  1.61776678],
#        [ 0.2483939 , -1.24041372, -1.38946701, ...,  0.29786698,
#          0.75823203,  1.66590028],
#        ...,
#        [-1.47884847,  1.2662214 , -0.68055527, ...,  1.28951423,
#          1.74578885,  1.56963329],
#        [-0.90310101, -0.09912061,  1.44617995, ...,  1.18513031,
#          1.49889965,  1.76216727],
#        [-1.47884847,  0.64207781,  0.73726821, ..., -0.7981642 ,
#          1.64703317, -1.17397595]])

# %%
x_test
# Out:
# array([[-0.90310101, -0.59683538,  1.44617995, ..., -1.47665969,
#          1.10387692, -0.21130605],
#        [ 0.82414136, -1.44317368, -1.38946701, ...,  0.24567502,
#          0.70885418,  0.07749493],
#        [ 0.82414136,  0.80538457,  0.02835647, ..., -1.42446773,
#          0.90636555,  0.79949736],
#        ...,
#        [-0.32735355,  1.3096577 , -1.38946701, ...,  1.55047403,
#         -0.08119128, -0.88517498],
#        [ 0.82414136, -0.79066773, -1.38946701, ..., -1.11131596,
#          1.2026326 , -0.35570653],
#        [-0.32735355,  0.14055163,  1.44617995, ..., -0.7981642 ,
#          0.56072066,  0.22189541]])

# %%
Y_test
# Out:
#      current price
# 521       383570.5
# 737       506854.0
# 740       146223.0
# 660       168854.5
# 411       507799.0
# ..             ...
# 468       320391.5
# 935       447337.0
# 428       275781.0
# 7         467471.5
# 155       291810.0
#
# [300 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
linear = LinearRegression()
linear.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score,accuracy_score,mean_squared_error

# %%
predicted = linear.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
r2 = r2_score(Y_test,predicted)

# %%
r2
# Out:
# -6.04275815407479

# %%
MSE  = mean_squared_error(10**Y_test,10**predicted )

# %%
MSE
# Out:
# 895605731728.6324

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()
params = {"n_neighbors": [x for x in range(1,21, 2)]}
search = GridSearchCV(knn, params, cv=10)
search.fit(x_train, Y_train)
print("best paramter: ", search.best_params_["n_neighbors"])
# Out:
# best paramter:  13

# %%
knn = KNeighborsRegressor(n_neighbors=7)
knn.fit(x_train, Y_train)
y_pred = knn.predict(x_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
mse = mean_squared_error(Y_test, y_pred)
mae = mean_absolute_error(Y_test, y_pred)
r2 = r2_score(Y_test, y_pred)
print("mse : ", mse)
print("mae: ", mae)
print("r2: ", r2)
# Out:
# mse :  3771059241.9619384
# mae:  49344.91714285714
# r2:  0.756819061159183

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeRegressor()

# %%
clf = clf.fit(x_train, Y_train)

# %%
cl_pre = clf.predict(x_test)

# %%
r2_score(Y_test,cl_pre)
# Out:
# 0.7588275299823611

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
random = RandomForestRegressor(n_estimators=100, random_state=42)
random.fit(x_train, Y_train)
# Out:
# <ipython-input-121-2e83e3aa0569>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   random.fit(x_train, Y_train)
# RandomForestRegressor(random_state=42)

# %%
ran_pred = random.predict(x_test)

# %%
r2_score(Y_test,ran_pred)
# Out:
# 0.8835685553085006
